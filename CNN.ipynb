# %% [markdown]
# <a href="https://colab.research.google.com/github/insoucyant/MachineLearning/blob/main/CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torchvision
import torchvision.transforms as transforms

# %%
torch.cuda.is_available()
# Out:
# True

# %%
device = 'cuda:0' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda:0'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
transform = transforms.ToTensor()
batch_size = 8
trainset = torchvision.datasets.FashionMNIST(root='./data', train=True, download=True, transform=transform)
testset = torchvision.datasets.FashionMNIST(root='./data', train=False, download=True, transform=transform)
classes = ('T-shirt/top', 'Trouser/pants','Pullover shirt','Dress','Coat','Sandal',
           'Shirt','Sneaker','Bag','Ankle boot')
# Out:
# ...
# 100%|██████████| 26.4M/26.4M [00:00<00:00, 114MB/s]
# Extracting ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# ...
# 100%|██████████| 29.5k/29.5k [00:00<00:00, 14.9MB/s]
# Extracting ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw
#
# ...
# 100%|██████████| 4.42M/4.42M [00:00<00:00, 58.7MB/s]
# Extracting ./data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# ...
# 100%|██████████| 5.15k/5.15k [00:00<00:00, 16.4MB/s]
# Extracting ./data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw

# %%
train_iter = iter(trainset)
image,label = next(train_iter)
image,label = next(train_iter)
image,label = next(train_iter)
image,label = next(train_iter)
image.shape, label
# Out:
# (torch.Size([1, 28, 28]), 3)

# %%
torch.min(image).item(), torch.max(image).item()
# Out:
# (0.0, 1.0)

# %%
np_img = image.numpy()
print(classes[label])
# plt.imshow(np.transpose(np_img,(1,2,0)))
# plt.show()
# Pytorch tensors by default have number of channels in the front. An RGB image has 3 channels. Grey Scale means 1 channel.
#  Channels are at the front in Pytorch. Move that to the back.
plt.imshow(np_img.reshape(28,28,1))
# Out:
# Dress
